# %% [markdown]
# # Import Modules and Assign Aliases

# %% [markdown]
# Here we will be importing numpy, tensorflow, and abspath to read in data

# %%
import tensorflow as tf
import numpy as np
from sklearn import datasets
from os.path import abspath
import matplotlib.pyplot as plt

# %%
features = [
    'raw_on'
    ,'raw_off'
    ,'slope'
    ,'aspect'
    ,'solar'
    ,'veg_h'
    ,'snow_off'
    ,'snow_on'
]

sitename = 'walton_creek'
sitename = 'buffalo_pass'
sitename = 'spring_creek'

# %%
data = {}

# %%
for f in features:

    # ---------------------------------------- #
    # open the file for reading (thus the "r") #
    # ---------------------------------------- #

    data[f] = np.loadtxt(f'../data/{f}_{sitename}.asc', skiprows=6)
    
    # --------------------------------------------- #
    # read the entire file contents into a variable #
    # --------------------------------------------- #

# %%
plt.imshow(data['snow_off'])

# %%
plt.figure(figsize=(10,10))
plt.imshow(
   data['snow_on']
)
plt.colorbar()
